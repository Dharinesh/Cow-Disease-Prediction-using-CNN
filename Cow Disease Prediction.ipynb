# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D
from keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
import ipywidgets as widgets
from PIL import Image
import os
import keras
import io
import tqdm
import cv2
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\dhari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X_train = []
y_train = []
image_size = 150

folderPath ='E:\Cow Disease Prediction\healthycows'
for j in os.listdir(folderPath):
    img = cv2.imread(os.path.join(folderPath,j))
    img = cv2.resize(img,(image_size, image_size))
    X_train.append(img)
    y_train.append(0)
folderPath ='E:\Cow Disease Prediction\lumpycows'
for j in os.listdir(folderPath):
    img = cv2.imread(os.path.join(folderPath,j))
    img = cv2.resize(img,(image_size, image_size))
    X_train.append(img)
    y_train.append(1)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

X_train,y_train=shuffle(X_train,y_train,random_state=101)
X_train.shape
# Out:
# (936, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_train,y_train,test_size=.1,random_state=101)

# %%
y_train.shape
# Out:
# (842,)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150,150, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(4, activation='softmax'))
# Out:
# WARNING:tensorflow:From c:\Users\dhari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\dhari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 64)      18496
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 73, 73, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 64)        36928
#
#  dropout_1 (Dropout)         (None, 69, 69, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 34, 34, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 34, 34, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 128)       147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 512)               3277312
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 4447044 (16.96 MB)
# Trainable params: 4447044 (16.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='Adam',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\dhari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
callbacks = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')
best_model_file = '/content/CNN_aug_best_weights.h5'
best_model = ModelCheckpoint(best_model_file, monitor='val_acc', verbose = 1, save_best_only = True)

# %%
history=model.fit(X_train,y_train,epochs=27,validation_split=.1,callbacks=[best_model])
# Out:
# Epoch 1/27
# WARNING:tensorflow:From c:\Users\dhari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\dhari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 24/24 [==============================] - ETA: 0s - loss: 4.0937 - accuracy: 0.5152WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 27s 1s/step - loss: 4.0937 - accuracy: 0.5152 - val_loss: 0.8589 - val_accuracy: 0.4941
# Epoch 2/27
# 24/24 [==============================] - ETA: 0s - loss: 0.7005 - accuracy: 0.5416WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 22s 901ms/step - loss: 0.7005 - accuracy: 0.5416 - val_loss: 1.0018 - val_accuracy: 0.5059
# Epoch 3/27
# 24/24 [==============================] - ETA: 0s - loss: 0.6990 - accuracy: 0.5429WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 21s 870ms/step - loss: 0.6990 - accuracy: 0.5429 - val_loss: 0.8747 - val_accuracy: 0.5059
# Epoch 4/27
# 24/24 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.5258WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 21s 863ms/step - loss: 0.6892 - accuracy: 0.5258 - val_loss: 0.7646 - val_accuracy: 0.6824
# Epoch 5/27
# 24/24 [==============================] - ETA: 0s - loss: 0.6579 - accuracy: 0.5984WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 21s 865ms/step - loss: 0.6579 - accuracy: 0.5984 - val_loss: 0.7394 - val_accuracy: 0.6588
# Epoch 6/27
# 24/24 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.6592WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 21s 862ms/step - loss: 0.6229 - accuracy: 0.6592 - val_loss: 0.5645 - val_accuracy: 0.7882
# Epoch 7/27
# 24/24 [==============================] - ETA: 0s - loss: 0.6505 - accuracy: 0.6380WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 21s 863ms/step - loss: 0.6505 - accuracy: 0.6380 - val_loss: 0.7110 - val_accuracy: 0.4941
# Epoch 8/27
# 24/24 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.6262WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 22s 901ms/step - loss: 0.6351 - accuracy: 0.6262 - val_loss: 0.6766 - val_accuracy: 0.6118
# Epoch 9/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5969 - accuracy: 0.7094WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 759ms/step - loss: 0.5969 - accuracy: 0.7094 - val_loss: 0.5366 - val_accuracy: 0.8000
# Epoch 10/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5845 - accuracy: 0.6988WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 17s 718ms/step - loss: 0.5845 - accuracy: 0.6988 - val_loss: 0.5251 - val_accuracy: 0.7882
# Epoch 11/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5877 - accuracy: 0.7041WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 759ms/step - loss: 0.5877 - accuracy: 0.7041 - val_loss: 0.5479 - val_accuracy: 0.8118
# Epoch 12/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5584 - accuracy: 0.7305WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 19s 782ms/step - loss: 0.5584 - accuracy: 0.7305 - val_loss: 0.5036 - val_accuracy: 0.8118
# Epoch 13/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7226WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 750ms/step - loss: 0.5443 - accuracy: 0.7226 - val_loss: 0.5642 - val_accuracy: 0.7294
# Epoch 14/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5500 - accuracy: 0.7424WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 759ms/step - loss: 0.5500 - accuracy: 0.7424 - val_loss: 0.5693 - val_accuracy: 0.7412
# Epoch 15/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5305 - accuracy: 0.7450WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 764ms/step - loss: 0.5305 - accuracy: 0.7450 - val_loss: 0.4852 - val_accuracy: 0.8235
# Epoch 16/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5266 - accuracy: 0.7239WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 19s 778ms/step - loss: 0.5266 - accuracy: 0.7239 - val_loss: 0.5361 - val_accuracy: 0.7765
# Epoch 17/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5229 - accuracy: 0.7318WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 763ms/step - loss: 0.5229 - accuracy: 0.7318 - val_loss: 0.4661 - val_accuracy: 0.7765
# Epoch 18/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.7768WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 17s 712ms/step - loss: 0.4785 - accuracy: 0.7768 - val_loss: 0.4573 - val_accuracy: 0.8000
# Epoch 19/27
# 24/24 [==============================] - ETA: 0s - loss: 0.5266 - accuracy: 0.7464WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 757ms/step - loss: 0.5266 - accuracy: 0.7464 - val_loss: 0.5577 - val_accuracy: 0.7294
# Epoch 20/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4823 - accuracy: 0.7741WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 758ms/step - loss: 0.4823 - accuracy: 0.7741 - val_loss: 0.4764 - val_accuracy: 0.8118
# Epoch 21/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4606 - accuracy: 0.7913WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 767ms/step - loss: 0.4606 - accuracy: 0.7913 - val_loss: 0.5218 - val_accuracy: 0.7882
# Epoch 22/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.7873WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 742ms/step - loss: 0.4728 - accuracy: 0.7873 - val_loss: 0.4926 - val_accuracy: 0.8118
# Epoch 23/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4628 - accuracy: 0.7926WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 741ms/step - loss: 0.4628 - accuracy: 0.7926 - val_loss: 0.4851 - val_accuracy: 0.8118
# Epoch 24/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8177WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 753ms/step - loss: 0.4215 - accuracy: 0.8177 - val_loss: 0.5225 - val_accuracy: 0.7882
# Epoch 25/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.8071WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 19s 794ms/step - loss: 0.4249 - accuracy: 0.8071 - val_loss: 0.6020 - val_accuracy: 0.7176
# Epoch 26/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8111WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 767ms/step - loss: 0.4363 - accuracy: 0.8111 - val_loss: 0.5007 - val_accuracy: 0.7412
# Epoch 27/27
# 24/24 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8045WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 24/24 [==============================] - 18s 751ms/step - loss: 0.4138 - accuracy: 0.8045 - val_loss: 0.4728 - val_accuracy: 0.7765

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
# Out:
# 3/3 [==============================] - 1s 167ms/step

# %%
y_test.shape
pred.shape
# Out:
# (94,)

# %%
accuracy = np.sum(pred==y_test)/np.size(pred)
print("Accuracy on testing dataset: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy on testing dataset: 73.40%
